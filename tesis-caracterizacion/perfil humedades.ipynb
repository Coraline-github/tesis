# %%
import numpy as np
from matplotlib import pyplot as plt

# %% [markdown]
# Perfil pozo 1

# %%
#seco
a1 = np.mean([0.246, 0.246, 0.246, 0.246, 0.246, 0.246, 0.244, 0.246, 0.246, 0.246, 0.244, 0.244, 0.244, 0.244, 0.244, 0.244, 0.244])
a2 = np.mean([0.279, 0.273, 0.275, 0.273, 0.279, 0.273, 0.273, 0.275, 0.275, 0.279, 0.277, 0.275, 0.277, 0.275, 0.277, 0.275, 0.279, 0.277])
a3 = np.mean([0.288, 0.290, 0.288, 0.288, 0.286, 0.294, 0.286, 0.292, 0.288, 0.288, 0.292, 0.292, 0.292, 0.288])
a4 = np.mean([0.303, 0.301, 0.301, 0.301, 0.303, 0.303, 0.298, 0.303, 0.303, 0.301, 0.301, 0.301, 0.301, 0.301, 0.301, 0.301])
a5 = np.mean([0.307, 0.307, 0.307, 0.307, 0.307, 0.307, 0.307, 0.307, 0.307, 0.307, 0.305, 0.305, 0.305, 0.305, 0.305, 0.305, 0.305, 0.305, 0.305, 0.305, 0.305, 0.305, 0.305])
a6 = np.mean([0.354, 0.352, 0.357, 0.350, 0.352, 0.357, 0.357, 0.352, 0.357, 0.357, 0.357, 0.355, 0.357, 0.350, 0.357, 0.350])
a7 = np.mean([0.336, 0.336, 0.335, 0.335, 0.335, 0.333, 0.333, 0.335, 0.335, 0.335, 0.333, 0.333, 0.333, 0.333, 0.333, 0.333, 0.335, 0.335, 0.333, 0.333, 0.340, 0.333])

# %%
#mojado
b1 = np.mean([0.299, 0.303, 0.300, 0.300,0.305, 0.302, 0.299, 0.304, 0.301, 0.299, 0.299, 0.304, 0.304, 0.303, 0.303, 0.299, 0.299, 0.304])
b2 = np.mean([0.228, 0.230, 0.225, 0.255, 0.232, 0.227, 0.232, 0.229, 0.228, 0.227, 0.225, 0.232, 0.229, 0.231, 0.225, 0.229, 0.227, 0.227])
b3 = np.mean([0.292, 0.294, 0.292, 0.297, 0.296, 0.294, 0.297, 0.296, 0.296, 0.296, 0.296, 0.296, 0.297])
b4 = np.mean([0.292, 0.290, 0.292, 0.296, 0.296, 0.296, 0.290, 0.296, 0.296, 0.292, 0.292, 0.292, 0.290, 0.294, 0.290])
b5 = np.mean([0.350, 0.350, 0.350, 0.348, 0.350, 0.351, 0.353, 0.351, 0.354, 0.351, 0.353, 0.351, 0.346, 0.351, 0.351, 0.353])
b6 = np.mean([0.324, 0.322, 0.322, 0.322, 0.322, 0.324, 0.322, 0.322, 0.322, 0.319, 0.324, 0.322, 0.326, 0.326, 0.322, 0.321, 0.316, 0.316, 0.324, 0.324, 0.326, 0.326])
b7 = np.mean([0.337, 0.341, 0.341, 0.343, 0.341, 0.336, 0.341, 0.339, 0.338, 0.340, 0.338, 0.337, 0.337, 0.337, 0.335, 0.337, 0.335, 0.340, 0.335, 0.335])

# %%
a = (a1, a2, a3, a4, a5, a6, a7)
b = (b1, b2, b3, b4, b5, b6, b7)
x = np.arange(3, 24,3)

plt.figure(figsize=(16,10))
plt.plot(x,a,'o-g',label='seco')
plt.plot(x,b,'o-b',label='mojado')
plt.grid('on')
plt.legend(loc="best",fontsize=15)
plt.xlabel("profundidad", color = 'k', fontsize=15)
plt.ylabel("humedad", color ='k', fontsize=15)
plt.title( 'Hueco 1' ,color ='k', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Hueco 1')

# %% [markdown]
# Perfil pozo 2

# %%
c1 = np.mean([0.099, 0.099, 0.099, 0.099, 0.099, 0.099, 0.101, 0.101, 0.101, 0.101, 0.101, 0.101, 0.101, 0.099])
c2 = np.mean([0.096, 0.093, 0.093, 0.090, 0.091, 0.093, 0.093, 0.088, 0.093, 0.093, 0.093, 0.091, 0.093, 0.091, 0.095, 0.091])
c3 = np.mean([0.099, 0.099, 0.099, 0.099, 0.101, 0.101, 0.101, 0.101, 0.101, 0.101, 0.104, 0.104, 0.104, 0.104, 0.101, 0.101, 0.101])
c4 = np.mean([0.094, 0.095, 0.098, 0.100, 0.100, 0.098, 0.091, 0.095, 0.097, 0.097, 0.095, 0.097, 0.097, 0.097, 0.095, 0.097, 0.095])
c5 = np.mean([0.099, 0.104, 0.104, 0.104, 0.098, 0.104, 0.101, 0.101, 0.106, 0.104, 0.098, 0.098, 0.098, 0.098, 0.098, 0.104, 0.104, 0.106, 0.098])
c6 = np.mean([0.188, 0.185, 0.190, 0.188, 0.188, 0.186, 0.188, 0.188, 0.186, 0.188, 0.188, 0.188, 0.188, 0.186, 0.188])

# %%
d1=np.mean([0.083, 0.078, 0.078, 0.078, 0.076, 0.081, 0.079, 0.079, 0.079, 0.084, 0.079, 0.082, 0.084, 0.079, 0.082, 0.079])
d2=np.mean([0.109, 0.110, 0.113, 0.109, 0.111, 0.110, 0.113, 0.111, 0.113, 0.109, 0.111, 0.112, 0.110, 0.113, 0.109, 0.110])
d3=np.mean([0.111, 0.109, 0.112, 0.112, 0.111, 0.111, 0.115, 0.112, 0.109, 0.105, 0.109, 0.109, 0.109, 0.110, 0.109, 0.109, 0.107, 0.111, 0.109, 0.109])
d4=np.mean([0.116, 0.122, 0.120, 0.120, 0.122, 0.121, 0.122, 0.120, 0.122, 0.119, 0.117, 0.118, 0.122, 0.117, 0.119, 0.122, 0.120, 0.117])
d5=np.mean([0.111, 0.111, 0.111, 0.111, 0.111, 0.111, 0.111, 0.111, 0.111, 0.114, 0.110, 0.111, 0.111, 0.111, 0.113, 0.113, 0.110, 0.114, 0.114, 0.110, 0.114])
d6=np.mean([0.152, 0.156, 0.154, 0.155, 0.156, 0.154, 0.155, 0.155, 0.155, 0.155, 0.158, 0.156, 0.153, 0.156, 0.156, 0.154])

# %%
c = (c1, c2, c3, c4, c5, c6)
d = (d1, d2, d3, d4, d5, d6)
x = np.arange(3, 21,3)

plt.figure(figsize=(16,10))
plt.plot(x,c,'o-g',label='seco')
plt.plot(x,d,'o-b',label='mojado')
plt.grid('on')
plt.legend(loc="best",fontsize=15)
plt.xlabel("profundidad", color = 'k', fontsize=15)
plt.ylabel("humedad", color ='k', fontsize=15)
plt.title( 'Hueco 2' ,color ='k', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Hueco 2')
